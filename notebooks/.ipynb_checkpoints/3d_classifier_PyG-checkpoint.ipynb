# %%
# Load Datasets
import sys
#sys.path.append("/home/mescalin/mgeyer/.local/lib/python3.8/site-packages/")
#sys.path.append("/home/mescalin/mgeyer/.local/lib/python3.8/site-packages/torch")
import os
import datetime
import numpy as np
import torch as th
import torch_geometric.transforms as T
from torch_geometric.loader import DenseDataLoader, DataLoader
import torch.nn.functional as F
import matplotlib.pyplot as plt

sys.path.append("../classifier/")
from model.data import CGDataset, VectorCGDataset, NeighbourCGDataset
from model.model import DiffCG, MinCutCG, DMoNCG, DeepCG
from run.train import training
from run.test import test


print("Pytorch Version", th.__version__)
print("Cuda is available:", th.cuda.is_available())

device = th.device("cuda" if th.cuda.is_available() else "cpu")
print("Using device:", device)

vectorize = True
k = 0

dataset_dict = {c.__name__: c for c in {CGDataset, VectorCGDataset, NeighbourCGDataset}}

if vectorize:
    dataset_v = "VectorCGDataset"
elif k > 0:
    dataset_v = "NeighbourCGDataset"
else:
    dataset_v = "CGDataset"

#Training Set
training_dir = "../data/train_set"
rmsd_list = "../data/truncated_train_rmsd.txt" #"data/train_rmsd_list.txt" #
training_dataset = dataset_dict[dataset_v](training_dir, rmsd_list, k=k)# T.NormalizeScale()) #, transform=transform_fn

#Validation Set
val_dir = "../data/val_set"
val_rmsd = "../data/val_rmsd_list.txt"
val_dataset = dataset_dict[dataset_v](val_dir, val_rmsd, k=k)#, transform=T.NormalizeScale()) #, transform=transform_fn

#Test Data
test_dir = "../data/test_set"
test_rmsd = "../data/test_rmsd_list.txt"
test_dataset = dataset_dict[dataset_v](test_dir, test_rmsd, k=k)#, transform=T.NormalizeScale()) #, transform=transform_fn

#5S rRNA and tRNA Test Data (previous training data)
st_test_dir = "../data/old_training_set"
st_test_rmsd = "../data/old_train_rmsd_list.txt"
st_test_dataset = dataset_dict[dataset_v](st_test_dir, st_test_rmsd, k=k)#, transform=T.NormalizeScale()) #, transform=transform_fn

#Rotated Test Sets
test_dir_rot = "../data/test_set_rot"
test_rmsd = "../data/test_rmsd_list.txt"
rot_test_dataset = dataset_dict[dataset_v](test_dir_rot, test_rmsd, k=k)#, transform=T.NormalizeScale()) #, transform=transform_fn

fst_test_rot = "../data/5st_test_rot"
fst_rot_dataset = dataset_dict[dataset_v](fst_test_rot, st_test_rmsd, k=k)#, transform=T.NormalizeScale()) #, transform=transform_fn
# Out:
# Pytorch Version 1.12.0+cu113
# Cuda is available: False
# Using device: cpu

# %% [markdown]
# TODO:
# *  Should Vector and Neighbour datasets inherit from CGDataset, to avoid code duplication?
# *  Add further that start of s1 is in yz-plane with s0 **Semi-DONE** (theres still a range of angles)
# *  are there additional tertiary interactions detected to add?
# *  softplus or relu for last classification step? if any non-linearity that ensures that no negative results are returned?
# *  try skip-cat/-sum in layer architecture?
#     * use the module `JumpingKnowledge` in PyG
#
# Normalization:
# *  BatchNorm: no improvement seen, maybe with larger datasets?
# *  PairNorm: Training took longer, results were nonsense
# *  DiffGroupNorm: figure out how to configure it (in channels not the same as for the layers)
# *  GraphNorm: Strange results, try again. (maybe with GINConv layers, as is shown in the paper?), doesnt seem to work in this case (at least with normal data)
# *  LayerNorm: Training took longer, results were worse than without norm
# *  InstanceNorm: doesnt work for 3D input? --> try pytorch instancenorm1(?)d instead of pygs
#
# --> try data normalization/standardization (beforehand)

# %%
#model = MinCutCG(training_dataset.num_node_features)
model = DeepCG(training_dataset.num_node_features, [3, 4, 23, 3]) #[3, 8, 36, 3]) #
#model = DMoNCG(training_dataset.num_node_features)

# %%
#Training
parent_dir = "../run_data/"

#with th.autograd.detect_anomaly():
training(
    model=model,
    train_dataset=training_dataset,
    val_dataset=val_dataset,
    model_dir=parent_dir,
    device=device,
    b_size=64,
    lr=1e-3,
    epochs=500,
    sched_T0=25,
    vectorize=vectorize,
    k=k,
    #num_workers=0,
    #resume="../run_data/2022-07-04_10-2_MinCutCG/model_data/epoch_1999.pth",
    burn_in=50)
# Out:
# 13.07.2022 15:42:20 Creating Training Directory at ../run_data/2022-07-13_15-42_DeepCG/
# 13.07.2022 15:42:20 Using CUDNN Benchmark
# 13.07.2022 15:42:20 Loading Datasets
# 13.07.2022 15:42:20 Start Training
# Epoch 0: Training loss 16.8480; Validation loss 21.6683, MAE: 22.1293; lr: 0.00000
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 5: Training loss 16.1946; Validation loss 21.3216, MAE: 21.7959; lr: 0.00020
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 10: Training loss 11.9290; Validation loss 17.8748, MAE: 18.3717; lr: 0.00040
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 15: Training loss 3.7679; Validation loss 14.3458, MAE: 14.8389; lr: 0.00060
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 20: Training loss 2.8465; Validation loss 13.9279, MAE: 14.4221; lr: 0.00080
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 25: Training loss 2.3199; Validation loss 13.4056, MAE: 13.8952; lr: 0.00100
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 30: Training loss 1.9902; Validation loss 13.7599, MAE: 14.2496; lr: 0.00080
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 35: Training loss 1.6694; Validation loss 13.7412, MAE: 14.2345; lr: 0.00060
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 40: Training loss 1.2228; Validation loss 13.8568, MAE: 14.3503; lr: 0.00040
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 45: Training loss 1.2293; Validation loss 13.9836, MAE: 14.4732; lr: 0.00020
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 50: Training loss 1.4266; Validation loss 13.8728, MAE: 14.3650; lr: 0.00000
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 55: Training loss 1.7788; Validation loss 13.5202, MAE: 14.0047; lr: 0.00090
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 60: Training loss 1.5398; Validation loss 13.5249, MAE: 14.0133; lr: 0.00065
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 65: Training loss 1.1579; Validation loss 13.9155, MAE: 14.4076; lr: 0.00035
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 70: Training loss 0.9228; Validation loss 13.8312, MAE: 14.3217; lr: 0.00010
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 75: Training loss 1.2107; Validation loss 13.8410, MAE: 14.3337; lr: 0.00100
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 80: Training loss 1.5667; Validation loss 14.3522, MAE: 14.8458; lr: 0.00090
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 85: Training loss 1.1993; Validation loss 14.0384, MAE: 14.5273; lr: 0.00065
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 90: Training loss 0.8306; Validation loss 13.9422, MAE: 14.4358; lr: 0.00035
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 95: Training loss 0.6821; Validation loss 13.9158, MAE: 14.4074; lr: 0.00010
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 100: Training loss 0.9065; Validation loss 13.9519, MAE: 14.4448; lr: 0.00100
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 105: Training loss 1.5092; Validation loss 13.8452, MAE: 14.3365; lr: 0.00090
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 110: Training loss 0.9333; Validation loss 13.8269, MAE: 14.3211; lr: 0.00065
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 115: Training loss 0.8458; Validation loss 13.7747, MAE: 14.2662; lr: 0.00035
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 120: Training loss 0.6236; Validation loss 13.7933, MAE: 14.2876; lr: 0.00010
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 125: Training loss 0.7813; Validation loss 13.8854, MAE: 14.3730; lr: 0.00100
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 130: Training loss 1.0985; Validation loss 13.8986, MAE: 14.3922; lr: 0.00090
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 135: Training loss 0.9547; Validation loss 13.7991, MAE: 14.2927; lr: 0.00065
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 140: Training loss 0.6017; Validation loss 14.0568, MAE: 14.5496; lr: 0.00035
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 145: Training loss 0.4888; Validation loss 13.9588, MAE: 14.4550; lr: 0.00010
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 150: Training loss 0.8744; Validation loss 14.0759, MAE: 14.5631; lr: 0.00100
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 155: Training loss 1.0886; Validation loss 14.1289, MAE: 14.6177; lr: 0.00090
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 160: Training loss 0.7130; Validation loss 13.6679, MAE: 14.1609; lr: 0.00065
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 165: Training loss 0.5112; Validation loss 13.8691, MAE: 14.3639; lr: 0.00035
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 170: Training loss 0.4128; Validation loss 13.9285, MAE: 14.4204; lr: 0.00010
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 175: Training loss 0.5997; Validation loss 13.6142, MAE: 14.1052; lr: 0.00100
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 180: Training loss 0.8855; Validation loss 14.0154, MAE: 14.5090; lr: 0.00090
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 185: Training loss 0.6686; Validation loss 14.0904, MAE: 14.5826; lr: 0.00065
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 190: Training loss 0.5791; Validation loss 13.7904, MAE: 14.2823; lr: 0.00035
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 195: Training loss 0.3282; Validation loss 13.8272, MAE: 14.3199; lr: 0.00010
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 200: Training loss 0.4364; Validation loss 14.0122, MAE: 14.5031; lr: 0.00100
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 205: Training loss 0.9733; Validation loss 14.0102, MAE: 14.5014; lr: 0.00090
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 210: Training loss 0.7156; Validation loss 13.7265, MAE: 14.2215; lr: 0.00065
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 215: Training loss 0.4045; Validation loss 13.9438, MAE: 14.4390; lr: 0.00035
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 220: Training loss 0.2543; Validation loss 13.7245, MAE: 14.2196; lr: 0.00010
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 225: Training loss 0.4959; Validation loss 13.7288, MAE: 14.2200; lr: 0.00100
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 230: Training loss 1.0499; Validation loss 13.8677, MAE: 14.3591; lr: 0.00090
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 235: Training loss 0.7253; Validation loss 13.7296, MAE: 14.2216; lr: 0.00065
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 240: Training loss 0.4301; Validation loss 13.7190, MAE: 14.2111; lr: 0.00035
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 245: Training loss 0.2961; Validation loss 13.8325, MAE: 14.3273; lr: 0.00010
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 250: Training loss 0.4507; Validation loss 13.5676, MAE: 14.0632; lr: 0.00100
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 255: Training loss 0.7093; Validation loss 14.2387, MAE: 14.7317; lr: 0.00090
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 260: Training loss 0.5705; Validation loss 13.6429, MAE: 14.1373; lr: 0.00065
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 265: Training loss 0.4129; Validation loss 13.7585, MAE: 14.2503; lr: 0.00035
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 270: Training loss 0.2532; Validation loss 13.6427, MAE: 14.1354; lr: 0.00010
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 275: Training loss 0.3338; Validation loss 13.5915, MAE: 14.0878; lr: 0.00100
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 280: Training loss 0.7231; Validation loss 13.7896, MAE: 14.2838; lr: 0.00090
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 285: Training loss 0.5095; Validation loss 13.6658, MAE: 14.1581; lr: 0.00065
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 290: Training loss 0.2688; Validation loss 13.7876, MAE: 14.2796; lr: 0.00035
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 295: Training loss 0.2159; Validation loss 13.6862, MAE: 14.1805; lr: 0.00010
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 300: Training loss 0.3336; Validation loss 13.5526, MAE: 14.0460; lr: 0.00100
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 305: Training loss 0.5939; Validation loss 13.5567, MAE: 14.0484; lr: 0.00090
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 310: Training loss 0.5182; Validation loss 13.5091, MAE: 14.0031; lr: 0.00065
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 315: Training loss 0.2893; Validation loss 13.6847, MAE: 14.1742; lr: 0.00035
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 320: Training loss 0.2191; Validation loss 13.6790, MAE: 14.1736; lr: 0.00010
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 325: Training loss 0.3556; Validation loss 13.4123, MAE: 13.9041; lr: 0.00100
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 330: Training loss 0.6655; Validation loss 13.9571, MAE: 14.4521; lr: 0.00090
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 335: Training loss 0.6167; Validation loss 13.7138, MAE: 14.2108; lr: 0.00065
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 340: Training loss 0.2468; Validation loss 13.5120, MAE: 14.0044; lr: 0.00035
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 345: Training loss 0.1877; Validation loss 13.6459, MAE: 14.1391; lr: 0.00010
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 350: Training loss 0.2858; Validation loss 13.7800, MAE: 14.2736; lr: 0.00100
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 355: Training loss 0.5187; Validation loss 13.9871, MAE: 14.4810; lr: 0.00090
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 360: Training loss 0.4994; Validation loss 13.8954, MAE: 14.3879; lr: 0.00065
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 365: Training loss 0.2228; Validation loss 13.6245, MAE: 14.1199; lr: 0.00035
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 370: Training loss 0.1801; Validation loss 13.6726, MAE: 14.1664; lr: 0.00010
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 375: Training loss 0.2181; Validation loss 13.8666, MAE: 14.3598; lr: 0.00100
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 380: Training loss 0.4836; Validation loss 13.6388, MAE: 14.1311; lr: 0.00090
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 385: Training loss 0.4062; Validation loss 13.7431, MAE: 14.2388; lr: 0.00065
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 390: Training loss 0.2493; Validation loss 13.7576, MAE: 14.2501; lr: 0.00035
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 395: Training loss 0.1578; Validation loss 13.7401, MAE: 14.2338; lr: 0.00010
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 400: Training loss 0.2692; Validation loss 13.8077, MAE: 14.3007; lr: 0.00100
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 405: Training loss 0.6514; Validation loss 13.7939, MAE: 14.2826; lr: 0.00090
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 410: Training loss 0.3585; Validation loss 13.8945, MAE: 14.3858; lr: 0.00065
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 415: Training loss 0.2038; Validation loss 13.5487, MAE: 14.0407; lr: 0.00035
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 420: Training loss 0.1142; Validation loss 13.6117, MAE: 14.1039; lr: 0.00010
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 425: Training loss 0.2203; Validation loss 13.6662, MAE: 14.1599; lr: 0.00100
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 430: Training loss 0.4811; Validation loss 13.7695, MAE: 14.2610; lr: 0.00090
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 435: Training loss 0.4782; Validation loss 14.0163, MAE: 14.5105; lr: 0.00065
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 440: Training loss 0.1755; Validation loss 13.6282, MAE: 14.1222; lr: 0.00035
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 445: Training loss 0.1277; Validation loss 13.6758, MAE: 14.1705; lr: 0.00010
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 450: Training loss 0.2262; Validation loss 13.9539, MAE: 14.4470; lr: 0.00100
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 455: Training loss 0.4618; Validation loss 14.0283, MAE: 14.5195; lr: 0.00090
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 460: Training loss 0.2852; Validation loss 13.5867, MAE: 14.0791; lr: 0.00065
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 465: Training loss 0.1761; Validation loss 13.7340, MAE: 14.2276; lr: 0.00035
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 470: Training loss 0.1141; Validation loss 13.7036, MAE: 14.1977; lr: 0.00010
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 475: Training loss 0.2195; Validation loss 13.3998, MAE: 13.8906; lr: 0.00100
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 480: Training loss 0.4881; Validation loss 13.6339, MAE: 14.1252; lr: 0.00090
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 485: Training loss 0.2449; Validation loss 13.5501, MAE: 14.0441; lr: 0.00065
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 490: Training loss 0.1724; Validation loss 13.6718, MAE: 14.1642; lr: 0.00035
# 	Add. Loss: Training 0.0000, Validation 0.0000
# Epoch 495: Training loss 0.1197; Validation loss 13.5881, MAE: 14.0817; lr: 0.00010
# 	Add. Loss: Training 0.0000, Validation 0.0000
# 13.07.2022 15:56:27 Training took 0.24 hours
# 13.07.2022 15:56:27 Minimum Training Loss 0.0847 in epoch 499
# 13.07.2022 15:56:27 Minimum Validation Loss (after 50 epochs) 13.2412 in epoch 404
# 13.07.2022 15:56:27 Minimum MAE (after 50 epochs) 13.7318 in epoch 404
# 13.07.2022 15:56:27 Seed used for training was: 10685708252937636299

# %%
#get training run data

run_dir = "/scr/risa/mgeyer/GCN/run_data/2022-07-15_14-38_DeepCG/"#"../run_data/2022-07-13_14-49_DeepCG"#
burn_in = 50

file_lines = []
with open(run_dir + "/loss_data.txt", "r") as fh:
    for line in fh.readlines():
        file_lines.append(line.rstrip("]\n").lstrip("[").split(","))

epoch_losses = [float(a) for a in file_lines[0]]
val_losses = [float(b) for b in file_lines[1]]
learning_rates = [float(c) for c in file_lines[2]]
mae_losses = [float(d) for d in file_lines[3]]
epoch_add_losses = [float(d) for d in file_lines[4]]

print(f"Minimum Training Loss {min(epoch_losses):.4f} in epoch {epoch_losses.index(min(epoch_losses))}")
print(f"Minimum Validation Loss (after {burn_in} epochs) {min(val_losses[burn_in:]):.4f} in epoch {val_losses.index(min(val_losses[burn_in:]))}")
print(f"Minimum MAE (after {burn_in} epochs) {min(mae_losses[burn_in:]):.4f} in epoch {mae_losses.index(min(mae_losses[burn_in:]))}")
# Out:
# Minimum Training Loss 0.0059 in epoch 1846
# Minimum Validation Loss (after 50 epochs) 12.7578 in epoch 52
# Minimum MAE (after 50 epochs) 13.2490 in epoch 52

# %%
#plot the training run
select = 52

print(f"Validation Loss at {select} is {val_losses[select]:.4f}")
print("5 before select")
print((", ").join([f"{x:.4f}" for x in val_losses[select-5:select]]))
print("5 after select")
print((", ").join([f"{y:.4f}" for y in val_losses[select+1:select+6]]))
print(f"MAE at {select} is {mae_losses[select]:.4f}")

fig, ax1 = plt.subplots(figsize=(20, 6))#layout="constrained", 
ax1.secondary_yaxis("left")
ax1.plot(epoch_losses, label="Training Loss")
ax1.plot(epoch_add_losses, "teal", label="Add. Loss Terms")
ax1.plot(val_losses, "r", label="Validation Loss")
ax1.plot(mae_losses, "orange", label="MAE (Val. Set)")

ax2 = ax1.twinx()
ax2.secondary_yaxis("right")
#ax2.plot(learning_rates, "g", label="Learning Rate")
plt.title("Training Run")
ax1.set_xlabel("Epochs")
ax1.set_ylabel("Mean RMSD difference")
ax2.set_ylabel("Learning rate")

ax1.set_ylim([(min(epoch_losses)-1), 20]) #max(val_losses)+2)
plt.axvline(x = select, c = "black", ls = ':')
ax1.axhline(y=0.0, linewidth=1, c = "black")#, ls = "--")
ax1.axhline(y=13, c = "black", ls = "--")

ax2.set_ylim([(min(learning_rates)), max(learning_rates)])

han1, lab1 = ax1.get_legend_handles_labels()
han2, lab2 = ax2.get_legend_handles_labels()
plt.legend(han1 + han2, lab1 + lab2, loc="upper right")
plt.draw()
# Out:
# Validation Loss at 52 is 12.7578
# 5 before select
# 13.8615, 13.1861, 13.0451, 13.2252, 13.7729
# 5 after select
# 13.8417, 13.0519, 13.3835, 13.7750, 13.7407
# MAE at 52 is 13.2490

# %%
#Test
from run.utility import rmsd_scatter, e_rmsd_scatter

# loss cutoff for type histo
cutoff = [10, 5]

train_loader = DataLoader(training_dataset, batch_size=1)
val_loader = DataLoader(val_dataset, batch_size=1)
test_dataloader = DataLoader(test_dataset, batch_size=1)
st_test_dataloader = DataLoader(st_test_dataset, batch_size=1)

model.to(device)
checkpoint = th.load(f"{run_dir}/model_data/epoch_{select}.pth", map_location=device)
print(f"Using state dict from epoch {checkpoint['epoch']}")
model.load_state_dict(checkpoint["model_state_dict"])

energy_l = []
true_rmsd_l = []
pred_rmsd_l = []
test_ls = []
for loader in [test_dataloader, st_test_dataloader, train_loader, val_loader]:
    if loader == test_dataloader:
        title = "Test Set"
        e_list = "../data/test_energy.txt"
    elif loader == st_test_dataloader:
        title = "5S and tRNA Test Set"
        e_list = "../data/old_train_energy.txt"
    elif loader == train_loader:
        title = "Training Set"
        e_list = "../data/train_energy.txt"
    elif loader == val_loader:
        title = "Validation Set"
        e_list = "../data/val_energy.txt"
    en, trs, prs, tlosses = test(model, loader, title, device, e_list, cutoff)
    if loader != train_loader:
        energy_l += en
        true_rmsd_l += trs
        pred_rmsd_l += prs
        test_ls += tlosses

        

rmsd_scatter(pred_rmsd_l, true_rmsd_l, test_ls, "All structures (w/o Train Set), Predicted RMSDs vs True RMSDs")
e_rmsd_scatter(energy_l, true_rmsd_l, "All structures (w/o Train Set), True RMSDS vs Energies")
e_rmsd_scatter(energy_l, pred_rmsd_l, "All structures (w/o Train Set), Predicted RMSDS vs Energies")
# Out:
# Using state dict from epoch 52
# Test Set
# Minimum Loss: Label = 17.5020, Prediction = 17.3202, Loss = 0.0165
# Maximum Loss: Label = 0.0000, Prediction = 33.4645, Loss = 32.9645
# Mean Test loss: 	 12.9745
# Std. Dev. of Test loss:  8.2718
# Min loss: 		 0.0165
# First Quantile: 	 6.6280
# Median: 		 11.1627
# Third Quantile: 	 18.8424
# Max Loss: 		 32.9645
# LinregressResult(slope=-0.7511618676430462, intercept=30.731209066701766, rvalue=-0.35380428038162615, pvalue=1.3701449658099673e-09, stderr=0.11974684597367359, intercept_stderr=2.3296625541416756)
# 5S and tRNA Test Set
# Minimum Loss: Label = 17.9010, Prediction = 17.8880, Loss = 0.0001
# Maximum Loss: Label = 0.1550, Prediction = 27.4516, Loss = 26.7966
# Mean Test loss: 	 4.4976
# Std. Dev. of Test loss:  4.9115
# Min loss: 		 0.0001
# First Quantile: 	 1.0034
# Median: 		 2.9622
# Third Quantile: 	 6.0134
# Max Loss: 		 26.7966
# LinregressResult(slope=0.7914165935313121, intercept=2.698563991049374, rvalue=0.6483918710169855, pvalue=3.455877294371949e-130, stderr=0.02826275079100094, intercept_stderr=0.5145435559214734)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [13], in <cell line: 21>()
#      32     title = "Validation Set"
#      33     e_list = "../data/val_energy.txt"
# ---> 34 en, trs, prs, tlosses = test(model, loader, title, device, e_list, cutoff)
#      35 if loader != train_loader:
#      36     energy_l += en
#
# File ~/.local/lib/python3.8/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~/3d_classifier/notebooks/../classifier/run/test.py:33, in test(model, loader, title, device, e_list, cutoff)
#      31 for test_graph in loader:
#      32     test_graph = test_graph.to(device)
# ---> 33     test_pred, _ = model(test_graph)
#      34     test_loss = F.smooth_l1_loss(test_pred, test_graph.y).item() # l1_loss(th.reshape(test_pred, (-1,)), test_graph.y).item() #
#      35     test_losses.append(float(test_loss))
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/3d_classifier/notebooks/../classifier/model/model.py:402, in DeepCG.forward(self, data)
#     400 #GCN2Conv
#     401 x = x_0 = self.pre(x)#, edge_index)
# --> 402 x = self.conv(x, x_0, edge_index, batch)
#     404 #GENConv
#     405 #x = self.pre(x)
#     406 #x = self.conv(x, edge_index, batch)
#     408 x = self.classify(x)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /tmp/mgeyer_pyg/tmprn7hv4z4.py:23, in Sequential_e60bae.forward(self, x0, x_0, edge_index, batch)
#      21 x2 = self.module_3(x, x_0, edge_index)
#      22 xs = self.module_4(x1, x2)
# ---> 23 x = self.module_5(xs)
#      24 x3 = self.module_6(x, x_0, edge_index)
#      25 xs = self.module_7(x2, x3)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.8/site-packages/torch_geometric/nn/models/jumping_knowledge.py:74, in JumpingKnowledge.forward(self, xs)
#      72 elif self.mode == 'lstm':
#      73     x = torch.stack(xs, dim=1)  # [num_nodes, num_layers, num_channels]
# ---> 74     alpha, _ = self.lstm(x)
#      75     alpha = self.att(alpha).squeeze(-1)  # [num_nodes, num_layers]
#      76     alpha = torch.softmax(alpha, dim=-1)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/rnn.py:769, in LSTM.forward(self, input, hx)
#     767 self.check_forward_args(input, hx, batch_sizes)
#     768 if batch_sizes is None:
# --> 769     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#     770                       self.dropout, self.training, self.bidirectional, self.batch_first)
#     771 else:
#     772     result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#     773                       self.num_layers, self.dropout, self.training, self.bidirectional)
#
# KeyboardInterrupt:

# %%
#Test run for rotational invariance
from scipy.stats import linregress
rot_test_dataloader = DataLoader(rot_test_dataset, batch_size=1)
fst_rot_dataloader = DataLoader(fst_rot_dataset, batch_size=1)

def rot_eval(dataloader, rot_dataloader):
    pred_dir = {}
    loss_dir = {}
    for loader in [dataloader, rot_dataloader]:
        with th.no_grad():
            model.eval()
            for test_graph in loader:
                test_graph = test_graph.to(device)
                test_pred, _ = model(test_graph)
                test_loss = F.smooth_l1_loss(test_pred, test_graph.y).item()

                if test_graph.name[0] not in pred_dir.keys():
                    pred_dir[test_graph.name[0]] = [float(test_pred)]
                else:
                    pred_dir[test_graph.name[0]].append(float(test_pred))
                
                if test_graph.name[0] not in loss_dir.keys():
                    loss_dir[test_graph.name[0]] = [float(test_loss)]
                else:
                    loss_dir[test_graph.name[0]].append(float(test_loss))
    return pred_dir, loss_dir

def rot_plot(pred_dir, loss_dir, title):
    test_preds = []
    trot_preds = []
    for a in pred_dir.keys():
        test_preds.append(pred_dir[a][0])
        trot_preds.append(pred_dir[a][1])

    test_ls = []
    trot_ls = []
    for b in loss_dir.keys():
        test_ls.append(loss_dir[b][0])
        trot_ls.append(loss_dir[b][1])

    reg = linregress(test_preds, trot_preds)
    print(reg)

    fig1, axs1 = plt.subplots(figsize=(8, 6)) #layout='constrained',
    plt.title(title + ", predicted RMSDs")
    axs1.scatter(test_preds, trot_preds)
    axs1.axline(xy1=(0, reg.intercept), slope=reg.slope, linestyle="--", color="k")
    axs1.text(max(test_preds), 0.01, f"R = {reg.rvalue:.4f}", fontsize=14, verticalalignment="bottom", horizontalalignment="right")
    plt.xlabel("Test RMSD")
    plt.ylabel("Rotated RMSD")
    plt.show()

    reg_l = linregress(test_ls, trot_ls)
    print(reg_l)

    fig2, axs2 = plt.subplots( figsize=(8, 6)) #layout='constrained',
    plt.title(title + ", test losses")
    axs2.scatter(test_ls, trot_ls)
    axs2.axline(xy1=(0, reg_l.intercept), slope=reg_l.slope, linestyle="--", color="k")
    axs2.text(max(test_ls), 0.01, f"R = {reg.rvalue:.4f}", fontsize=14, verticalalignment="bottom", horizontalalignment="right")
    plt.xlabel("Test RMSD loss")
    plt.ylabel("Rotated RMSD loss")
    plt.show()

test_pred_dir, test_loss_dir = rot_eval(test_dataloader, rot_test_dataloader)
rot_plot(test_pred_dir, test_loss_dir, "Test Set vs Rotated Test Set")

fst_pred_dir, fst_loss_dir = rot_eval(st_test_dataloader, fst_rot_dataloader)
rot_plot(fst_pred_dir, fst_loss_dir, "5st Set vs Rotated 5st Set")
# Out:
# LinregressResult(slope=0.8444808486943058, intercept=2.466309369267437, rvalue=0.8549240909876408, pvalue=2.3097994298691945e-80, stderr=0.030899867977820593, intercept_stderr=0.6044981453090565)
# LinregressResult(slope=0.874592401793293, intercept=1.0439311875615633, rvalue=0.9290718318223314, pvalue=8.64099255122842e-121, stderr=0.020997792109900902, intercept_stderr=0.2986067111160438)
# LinregressResult(slope=0.9587821986935745, intercept=0.736999149600976, rvalue=0.9619165941783716, pvalue=0.0, stderr=0.008286628299595523, intercept_stderr=0.15059816476149815)
# LinregressResult(slope=0.919581102331771, intercept=0.39323730815942515, rvalue=0.8998234324851364, pvalue=0.0, stderr=0.013559996757573106, intercept_stderr=0.08363657449607008)
